# %%
from bsread import source, SUB, PULL, PUSH, PUB
import matplotlib.pyplot as plt
import numpy as np

# %%
#from cam_server.utils import get_host_port_from_stream_address

port=9003
host = "sf-daqsync-03.psi.ch"
mode = SUB
num_shots = 100
x_corr = []
signal = []
att = []
edge_pos = []
with source(host=host, port=port, mode=SUB) as stream:
    for i in range(0,num_shots):
        message = stream.receive()
#         print(message.data.data.keys())
        x_corr.append(message.data.data['SAROP21-ATT01:xcorr'].value)
        signal.append(message.data.data['SAROP21-ATT01:signal'].value)
        att.append(message.data.data['SAROP21-ATT01:arrival_time'].value)
        edge_pos.append(message.data.data['SAROP21-ATT01:edge_pos'].value)
        
x_corr = np.asarray(x_corr)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-bc034bf9da00> in <module>
#      11 with source(host=host, port=port, mode=SUB) as stream:
#      12     for i in range(0,num_shots):
# ---> 13         message = stream.receive()
#      14 #         print(message.data.data.keys())
#      15         x_corr.append(message.data.data['SAROP21-ATT01:xcorr'].value)
#
# /opt/gfa/python-3.7/2018.12/lib/python3.7/site-packages/bsread/bsread.py in receive(self, filter, handler)
#     163             handler = self.handler.receive
#     164
# --> 165         message = self.stream.receive(handler=handler)
#     166
#     167         if filter:
#
# /opt/gfa/python-3.7/2018.12/lib/python3.7/site-packages/mflow/mflow.py in receive(self, handler, block)
#     197
#     198         try:
# --> 199             data = handler(self.receiver)
#     200             # as an extra safety margin
#     201             if data:
#
# /opt/gfa/python-3.7/2018.12/lib/python3.7/site-packages/bsread/handlers/compact.py in receive(self, receiver)
#      16
#      17         # Receive main header
# ---> 18         header = receiver.next(as_json=True)
#      19
#      20         # We cannot process an empty Header.
#
# /opt/gfa/python-3.7/2018.12/lib/python3.7/site-packages/mflow/mflow.py in next(self, as_json)
#     293             else:
#     294                 flags = 0 if self.block else zmq.NOBLOCK
# --> 295                 raw = self.socket.recv(flags=flags, copy=self.zmq_copy, track=self.zmq_track)
#     296
#     297             self.statistics.bytes_received += len(raw)
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /opt/gfa/python-3.7/2018.12/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
ind = 14
plt.figure()
plt.subplot(211)
plt.plot(x_corr[ind])
plt.subplot(212)
plt.plot(signal[ind])

# %%
plt.figure()
plt.hist(edge_pos)
# Out:
# /sf/photo/miniconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6575: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /sf/photo/miniconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6576: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-9f2b8906b735> in <module>
#       1 plt.figure()
# ----> 2 plt.hist(edge_pos)
#
# /sf/photo/miniconda/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# /sf/photo/miniconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /sf/photo/miniconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6589             # this will automatically overwrite bins,
#    6590             # so that each histogram uses the same bins
# -> 6591             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6592             m = m.astype(float)  # causes problems later if it's an int
#    6593             if mlast is None:
#
# /sf/photo/miniconda/lib/python3.6/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     778     a, weights = _ravel_and_check_weights(a, weights)
#     779
# --> 780     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     781
#     782     # Histogram is an integer or a float array depending on the weights.
#
# /sf/photo/miniconda/lib/python3.6/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     415             raise ValueError('`bins` must be positive, when an integer')
#     416
# --> 417         first_edge, last_edge = _get_outer_edges(a, range)
#     418
#     419     elif np.ndim(bins) == 1:
#
# /sf/photo/miniconda/lib/python3.6/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     302         if first_edge > last_edge:
#     303             raise ValueError(
# --> 304                 'max must be larger than min in range parameter.')
#     305         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     306             raise ValueError(
#
# ValueError: max must be larger than min in range parameter.
